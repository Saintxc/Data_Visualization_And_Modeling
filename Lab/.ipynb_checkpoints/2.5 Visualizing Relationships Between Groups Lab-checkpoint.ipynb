# %% [markdown]
# # Lab Instructions
#
# You are part of a data team for a financial institution that uses an AI model to determine who will and will not be granted a loan.  Recently, there have been complaints from customers that the model unfairly discriminates based on the applicant's age and sex. A court has ordered that the financial institution must provide information about how the model works.
#
# Data from recent loan applications is given in `loan_data.csv`.  The data dictionary is below:
#
# | Feature              | Description | Data Type |
# | :---------------- | :------: | ----: |
# |person_age|Age of the person|Float
# |person_gender|Gender of the person|Categorical
# |person_education|Highest education level|Categorical
# |person_income|Annual income|Float
# |person_emp_exp|Years of employment experience|Integer
# |person_home_ownership|Home ownership status (e.g., rent, own, mortgage)|Categorical
# |loan_amnt|Loan amount requested|Float
# |loan_intent|Purpose of the loan|Categorical
# |loan_int_rate|Loan interest rate|Float
# |loan_percent_income|Loan amount as a percentage of annual income|Float
# |cb_person_cred_hist_length|Length of credit history in years|Float
# |credit_score|Credit score of the person|Integer
# |previous_loan_defaults_on_file|Indicator of previous loan defaults|Categorical
# |loan_status (target variable)|Loan approval status: 1 = approved; 0 = rejected|Integer
#
# Visualize the relationship between age, sex and 5 other features with `loan_status`.  Which features seem to drive the model's decision to grant a loan?  Which seem unrelated?  Should the financial institution be concerned about potential legal trouble?  Make sure to justify your answers with specific references to your visualizations.

# %% [markdown]
# # My analysis
#
# Based on the features I chose to use for the graphs, heres what I interpret regarding the loans. The features most used to drive a decision for the loan would be `Credit Score, Previous Defaults, and Person Age`. Other features that impact the loan decision but not quite as severe would be `Loan Purpose`. The most unrelated to the decision is `Gender, Loan Amount, and Persons Income`. Based off the information I see within the graphs the financial insitution could face some legal trouble. With the features I have shown below, when you look at the ages for approved and denied loans, younger people are more likely to get approved versus someone who is older. This could easily open them up for age discrimination legal battles. As for the gender, males seem to be denied more often than females, but the denial rate for male and female are both significant so I don't think it plays a major role in the decision factor compared to age.

# %%
import pandas as pd

df = pd.read_csv('loan_data.csv')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x='loan_status', y= 'person_age', data=df)

plt.show()

# %%
sns.countplot(x='person_gender', hue='loan_status', data=df)

plt.show()

# %%
sns.boxplot(x="loan_status", y="credit_score", data=df)

plt.show()

# %%
sns.countplot(x="loan_intent", hue="loan_status", data=df)
plt.xticks(rotation=30, ha="right")

plt.show()

# %%
sns.countplot(x="previous_loan_defaults_on_file", hue="loan_status", data=df)

plt.show()

# %%
sns.boxplot(x="loan_status", y="loan_amnt", data=df)

plt.show()

# %%
sns.boxplot(x="loan_status", y="person_income", data=df)

plt.show()
